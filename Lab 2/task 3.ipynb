# %% [markdown]
# # Шкарбаненко Михаил, Б05-907

# %% [markdown]
# # Задача 3.1
#
# Выборка: набор предложений на русском языке с указанием частей речи для каждого слова.
#
# Требуется:
#
# * Рассмотреть последовательность частей речи как марковскую модель. Определить оптимальный порядок марковской модели.
#
# * Обучить скрытую марковскую модель по выборке. Оценить точность предсказания частей речи, посчитать энтропию на выборке.
# Важно: в целях ускорения эксперимента рекомендуется взять первые 10 МБ текста из выборки.

# %% [markdown]
# # Решение

# %% [markdown]
# ## 1. Подготовительная часть

# %% [markdown]
# ### Библиотеки

# %%
import os
if not os.path.isfile('/content/nerus_lenta.conllu.gz'):
  ! wget https://storage.yandexcloud.net/natasha-nerus/data/nerus_lenta.conllu.gz
# Out:
# --2023-05-09 13:07:58--  https://storage.yandexcloud.net/natasha-nerus/data/nerus_lenta.conllu.gz
# Resolving storage.yandexcloud.net (storage.yandexcloud.net)... 213.180.193.243, 2a02:6b8::1d9
# Connecting to storage.yandexcloud.net (storage.yandexcloud.net)|213.180.193.243|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1961465886 (1.8G) [application/octet-stream]
# Saving to: ‘nerus_lenta.conllu.gz’
#
# nerus_lenta.conllu. 100%[===================>]   1.83G  22.6MB/s    in 86s
#
# 2023-05-09 13:09:25 (21.9 MB/s) - ‘nerus_lenta.conllu.gz’ saved [1961465886/1961465886]

# %%
try:
  import nerus, nltk
except ModuleNotFoundError:
  ! pip install nerus
  ! pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting nerus
#   Downloading nerus-1.7.0-py3-none-any.whl (15 kB)
# Installing collected packages: nerus
# Successfully installed nerus-1.7.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2022.10.31)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.65.0)

# %%
import pandas as pd
import numpy as np
from numpy import transpose, log, sum as nsum, unique as nunique
from re import compile, Pattern
from sys import getsizeof
from nerus import load_nerus
from nltk.tag import hmm
from collections import Counter
from more_itertools import take
from scipy.stats.distributions import chi2
from seaborn import heatmap
from matplotlib.pyplot import figure
from sys import getsizeof
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Данные

# %%
dataset = load_nerus('nerus_lenta.conllu.gz')

# %%
def get_tokens(dataset, memory_limit):
  tokens = []
  while getsizeof(tokens) < memory_limit:
    for sent in next(dataset).sents:
      for token in sent.tokens:
        word = token.text.lower()
        pos = token.pos
        if compile('^[а-я]+$').match(word):
          tokens.append((word, pos))
  return tokens

# %%
tokens = get_tokens(dataset, 12 * 2 ** 20)

# %%
len(tokens)
# Out:
# 1503860

# %%
train_data, test_data = train_test_split(tokens, test_size=0.05, shuffle=False)

# %% [markdown]
# ## 2. Обучение и анализ модели

# %%
vocab_tags = set(tag for _, tag in train_data)
vocab_words = set(word for word, _ in train_data)
trainer = hmm.HiddenMarkovModelTrainer(vocab_tags, vocab_words)
model = trainer.train_supervised([train_data])

# %%
import random
def random_sample(list_, size):
  assert size <= len(list_)
  idx1 = random.randrange(0, len(list_) - size + 1)
  idx2 = idx1 + size
  return list_[idx1: idx2]

# %% [markdown]
# ### Качество модели на трейн датасете

# %%
model.test([train_data[0:5000]], verbose=True)
# Out:
# Test: по/ADP социальным/ADJ вопросам/NOUN татьяна/PROPN голикова/PROPN рассказала/VERB в/ADP каких/DET регионах/NOUN россии/PROPN зафиксирована/VERB наиболее/ADV высокая/ADJ смертность/NOUN от/ADP рака/NOUN сообщает/VERB риа/PROPN новости/PROPN по/ADP словам/NOUN голиковой/PROPN чаще/ADV всего/PRON онкологические/ADJ заболевания/NOUN становились/VERB причиной/NOUN смерти/NOUN в/ADP псковской/ADJ тверской/ADJ тульской/ADJ и/CCONJ орловской/ADJ областях/NOUN а/CCONJ также/ADV в/ADP севастополе/PROPN напомнила/VERB что/SCONJ главные/ADJ факторы/NOUN смертности/NOUN в/ADP россии/PROPN рак/NOUN и/CCONJ болезни/NOUN системы/NOUN кровообращения/NOUN в/ADP начале/NOUN года/NOUN стало/VERB известно/ADJ что/SCONJ смертность/NOUN от/ADP онкологических/ADJ заболеваний/NOUN среди/ADP россиян/NOUN снизилась/VERB впервые/ADV за/ADP три/NUM года/NOUN по/ADP данным/NOUN росстата/PROPN в/ADP году/NOUN от/ADP рака/NOUN умерли/VERB тысяч/NOUN человек/NOUN это/PRON на/ADP процента/NOUN меньше/NUM чем/SCONJ годом/NOUN ранее/ADV австрийские/ADJ правоохранительные/ADJ органы/NOUN не/PART представили/VERB доказательств/NOUN нарушения/NOUN российскими/ADJ биатлонистами/NOUN антидопинговых/ADJ правил/NOUN об/ADP этом/PRON сообщил/VERB посол/NOUN россии/PROPN в/ADP вене/PROPN дмитрий/PROPN любинский/PROPN по/ADP итогам/NOUN встречи/NOUN уполномоченного/VERB адвоката/NOUN дипмиссии/NOUN с/ADP представителями/NOUN прокуратуры/NOUN страны/NOUN передает/VERB тасс/PROPN действует/VERB презумпция/NOUN невиновности/NOUN ограничений/NOUN свободы/NOUN передвижения/NOUN для/ADP команды/NOUN нет/VERB добавили/VERB в/ADP посольстве/NOUN международный/ADJ союз/NOUN биатлонистов/NOUN также/ADV не/PART будет/AUX применять/VERB санкции/NOUN к/ADP российским/ADJ биатлонистам/NOUN все/DET они/PRON продолжат/VERB выступление/NOUN на/ADP кубке/PROPN мира/NOUN полиция/NOUN нагрянула/VERB в/ADP отель/NOUN сборной/NOUN россии/PROPN в/ADP хохфильцене/PROPN вечером/NOUN декабря/NOUN как/SCONJ написал/VERB биатлонист/NOUN александр/PROPN логинов/PROPN их/PRON считают/VERB виновными/ADJ в/ADP махинациях/NOUN с/ADP переливанием/NOUN крови/NOUN биатлонисту/NOUN антону/PROPN шипулину/PROPN также/ADV попавшему/VERB в/ADP список/NOUN полиция/NOUN нанесла/VERB отдельный/ADJ визит/NOUN сейчас/ADV он/PRON тренируется/VERB отдельно/ADV в/ADP австрийском/ADJ обертиллахе/PROPN обвинения/NOUN спортсмен/NOUN назвал/VERB бредом/NOUN а/CCONJ также/ADV указал/VERB на/ADP охоту/NOUN на/ADP ведьм/NOUN в/ADP мировом/ADJ биатлоне/NOUN в/ADP австрии/PROPN прием/NOUN допинга/NOUN уголовное/ADJ преступление/NOUN максимальное/ADJ наказание/NOUN за/ADP его/PRON употребление/NOUN три/NUM года/NOUN тюрьмы/NOUN сотрудники/NOUN социальной/ADJ сети/NOUN проанализировали/VERB поставленные/VERB пользователями/NOUN смайлики/NOUN геолокации/NOUN и/CCONJ хештеги/NOUN и/CCONJ опубликовали/VERB итоги/NOUN года/NOUN об/ADP этом/PRON сообщается/VERB на/ADP официальном/ADJ сайте/NOUN таким/DET образом/NOUN самой/ADJ счастливой/ADJ геолокацией/NOUN признал/VERB диснейленд/PROPN в/ADP токио/PROPN так/ADV как/SCONJ больше/NUM всего/PRON счастливых/ADJ смайликов/NOUN в/ADP году/NOUN пользователи/NOUN ставили/VERB именно/PART под/ADP фотографиями/NOUN из/ADP японского/ADJ диснейленда/PROPN также/ADV эксперты/NOUN назвали/VERB самый/ADJ популярный/ADJ фильтр/NOUN для/ADP лица/NOUN им/PRON стал/VERB фильтр/NOUN с/ADP сердечками/NOUN на/ADP глазах/NOUN а/CCONJ например/ADV самыми/ADJ часто/ADV используемыми/VERB хештегами/NOUN в/ADP году/NOUN были/AUX и/CCONJ в/ADP ноябре/NOUN сотрудники/NOUN британской/ADJ ассоциации/NOUN потребителей/NOUN составили/VERB рейтинг/NOUN самых/ADJ безопасных/ADJ стран/NOUN для/ADP путешествий/NOUN специалисты/NOUN проанализировали/VERB самых/ADJ популярных/ADJ туристических/ADJ направлений/NOUN по/ADP четырем/NUM критериям/NOUN уровень/NOUN преступности/NOUN угроза/NOUN здоровью/NOUN вероятность/NOUN теракта/NOUN и/CCONJ стихийных/ADJ бедствий/NOUN самой/ADJ безопасной/ADJ страной/NOUN по/ADP всем ...
#
# Untagged: по социальным вопросам татьяна голикова рассказала в каких регионах россии зафиксирована наиболее высокая смертность от рака сообщает риа новости по словам голиковой чаще всего онкологические заболевания становились причиной смерти в псковской тверской тульской и орловской областях а также в севастополе напомнила что главные факторы смертности в россии рак и болезни системы кровообращения в начале года стало известно что смертность от онкологических заболеваний среди россиян снизилась впервые за три года по данным росстата в году от рака умерли тысяч человек это на процента меньше чем годом ранее австрийские правоохранительные органы не представили доказательств нарушения российскими биатлонистами антидопинговых правил об этом сообщил посол россии в вене дмитрий любинский по итогам встречи уполномоченного адвоката дипмиссии с представителями прокуратуры страны передает тасс действует презумпция невиновности ограничений свободы передвижения для команды нет добавили в посольстве международный союз биатлонистов также не будет применять санкции к российским биатлонистам все они продолжат выступление на кубке мира полиция нагрянула в отель сборной россии в хохфильцене вечером декабря как написал биатлонист александр логинов их считают виновными в махинациях с переливанием крови биатлонисту антону шипулину также попавшему в список полиция нанесла отдельный визит сейчас он тренируется отдельно в австрийском обертиллахе обвинения спортсмен назвал бредом а также указал на охоту на ведьм в мировом биатлоне в австрии прием допинга уголовное преступление максимальное наказание за его употребление три года тюрьмы сотрудники социальной сети проанализировали поставленные пользователями смайлики геолокации и хештеги и опубликовали итоги года об этом сообщается на официальном сайте таким образом самой счастливой геолокацией признал диснейленд в токио так как больше всего счастливых смайликов в году пользователи ставили именно под фотографиями из японского диснейленда также эксперты назвали самый популярный фильтр для лица им стал фильтр с сердечками на глазах а например самыми часто используемыми хештегами в году были и в ноябре сотрудники британской ассоциации потребителей составили рейтинг самых безопасных стран для путешествий специалисты проанализировали самых популярных туристических направлений по четырем критериям уровень преступности угроза здоровью вероятность теракта и стихийных бедствий самой безопасной страной по всем параметрам стала исландия с начала расследования российского вмешательства в выборы власти сша потратили более миллионов долларов об этом сообщает со ссылкой на отчет министерства юстиции сша в документе содержатся данные о расходах на следствие с апреля по сентябрь года за эти полгода было потрачено миллиона долларов из которых почти миллиона долларов ушли на зарплату сотрудников тысяч на поездки и сопутствующие расходы ранее минюст сша уже публиковал отчеты о затратах на дело о российском вмешательстве за предыдущие месяцы декабря расследование спецпрокурора робера мюллера показало что по меньшей мере человек из окружения президента сша дональда трампа контактировали с россиянами во время его избирательной кампании и последующего переходного периода перед вступлением в должность главы государства мюллер с года ведет дело о якобы российском вмешательстве в американские выборы в перед ним поставлена задача выяснить был ли сговор между штабом трампа и россией кремль и белый дом отвергают все обвинения россию неоднократно обвиняли во вмешательстве в выборы президента сша с помощью хакеров в июне спецслужбы выдвинули заочное обвинение российским разведчикам по данным спецслужб сша российская разведка использовала две хакерские группировки для взлома серверов демократической партии хакерская группировка опубликовала новые документы о деятельности британского аналитического центра из материалов следует что центр получает финансирование от некого института государственного управления под руководством кристофера до ...
#
# HMM-tagged: по/ADP социальным/ADJ вопросам/NOUN татьяна/PROPN голикова/PROPN рассказала/VERB в/ADP каких/DET регионах/NOUN россии/PROPN зафиксирована/VERB наиболее/ADV высокая/ADJ смертность/NOUN от/ADP рака/NOUN сообщает/VERB риа/PROPN новости/PROPN по/ADP словам/NOUN голиковой/PROPN чаще/ADV всего/PART онкологические/ADJ заболевания/NOUN становились/VERB причиной/NOUN смерти/NOUN в/ADP псковской/ADJ тверской/ADJ тульской/ADJ и/CCONJ орловской/ADJ областях/NOUN а/CCONJ также/ADV в/ADP севастополе/PROPN напомнила/VERB что/SCONJ главные/ADJ факторы/NOUN смертности/NOUN в/ADP россии/PROPN рак/NOUN и/CCONJ болезни/NOUN системы/NOUN кровообращения/NOUN в/ADP начале/NOUN года/NOUN стало/VERB известно/ADJ что/SCONJ смертность/NOUN от/ADP онкологических/ADJ заболеваний/NOUN среди/ADP россиян/NOUN снизилась/VERB впервые/ADV за/ADP три/NUM года/NOUN по/ADP данным/NOUN росстата/PROPN в/ADP году/NOUN от/ADP рака/NOUN умерли/VERB тысяч/NOUN человек/NOUN это/PRON на/ADP процента/NOUN меньше/ADV чем/SCONJ годом/NOUN ранее/ADV австрийские/ADJ правоохранительные/ADJ органы/NOUN не/PART представили/VERB доказательств/NOUN нарушения/NOUN российскими/ADJ биатлонистами/NOUN антидопинговых/ADJ правил/NOUN об/ADP этом/PRON сообщил/VERB посол/NOUN россии/PROPN в/ADP вене/PROPN дмитрий/PROPN любинский/PROPN по/ADP итогам/NOUN встречи/NOUN уполномоченного/NOUN адвоката/NOUN дипмиссии/NOUN с/ADP представителями/NOUN прокуратуры/NOUN страны/NOUN передает/VERB тасс/PROPN действует/VERB презумпция/NOUN невиновности/NOUN ограничений/NOUN свободы/NOUN передвижения/NOUN для/ADP команды/NOUN нет/VERB добавили/VERB в/ADP посольстве/NOUN международный/ADJ союз/NOUN биатлонистов/NOUN также/ADV не/PART будет/AUX применять/VERB санкции/NOUN к/ADP российским/ADJ биатлонистам/NOUN все/PRON они/PRON продолжат/VERB выступление/NOUN на/ADP кубке/PROPN мира/NOUN полиция/NOUN нагрянула/VERB в/ADP отель/NOUN сборной/NOUN россии/PROPN в/ADP хохфильцене/PROPN вечером/NOUN декабря/NOUN как/SCONJ написал/VERB биатлонист/NOUN александр/PROPN логинов/PROPN их/PRON считают/VERB виновными/ADJ в/ADP махинациях/NOUN с/ADP переливанием/NOUN крови/NOUN биатлонисту/NOUN антону/PROPN шипулину/PROPN также/ADV попавшему/VERB в/ADP список/NOUN полиция/NOUN нанесла/VERB отдельный/ADJ визит/NOUN сейчас/ADV он/PRON тренируется/VERB отдельно/ADV в/ADP австрийском/ADJ обертиллахе/PROPN обвинения/NOUN спортсмен/NOUN назвал/VERB бредом/NOUN а/CCONJ также/ADV указал/VERB на/ADP охоту/NOUN на/ADP ведьм/NOUN в/ADP мировом/ADJ биатлоне/NOUN в/ADP австрии/PROPN прием/NOUN допинга/NOUN уголовное/ADJ преступление/NOUN максимальное/ADJ наказание/NOUN за/ADP его/DET употребление/NOUN три/NUM года/NOUN тюрьмы/NOUN сотрудники/NOUN социальной/ADJ сети/NOUN проанализировали/VERB поставленные/VERB пользователями/NOUN смайлики/NOUN геолокации/NOUN и/CCONJ хештеги/NOUN и/CCONJ опубликовали/VERB итоги/NOUN года/NOUN об/ADP этом/PRON сообщается/VERB на/ADP официальном/ADJ сайте/NOUN таким/DET образом/NOUN самой/ADJ счастливой/ADJ геолокацией/NOUN признал/VERB диснейленд/PROPN в/ADP токио/PROPN так/ADV как/SCONJ больше/ADV всего/PART счастливых/ADJ смайликов/NOUN в/ADP году/NOUN пользователи/NOUN ставили/VERB именно/PART под/ADP фотографиями/NOUN из/ADP японского/ADJ диснейленда/PROPN также/ADV эксперты/NOUN назвали/VERB самый/ADJ популярный/ADJ фильтр/NOUN для/ADP лица/NOUN им/PRON стал/VERB фильтр/NOUN с/ADP сердечками/NOUN на/ADP глазах/NOUN а/CCONJ например/ADV самыми/ADJ часто/ADV используемыми/VERB хештегами/NOUN в/ADP году/NOUN были/AUX и/CCONJ в/ADP ноябре/NOUN сотрудники/NOUN британской/ADJ ассоциации/NOUN потребителей/NOUN составили/VERB рейтинг/NOUN самых/ADJ безопасных/ADJ стран/NOUN для/ADP путешествий/NOUN специалисты/NOUN проанализировали/VERB самых/ADJ популярных/ADJ туристических/ADJ направлений/NOUN по/ADP четырем/NUM критериям/NOUN уровень/NOUN преступности/NOUN угроза/NOUN здоровью/NOUN вероятность/NOUN теракта/NOUN и/CCONJ стихийных/ADJ бедствий/NOUN самой/ADJ безопасной/ADJ страной/NOUN по/AD ...
#
# Entropy: 268.53828823223506
#
# ------------------------------------------------------------
# accuracy over 5000 tokens: 97.96

# %%
model.test([random_sample(train_data, 1000)], verbose=True)
# Out:
# Test: с/ADP мск/NOUN ноября/NOUN за/ADP введение/NOUN в/ADP ряде/NOUN областей/NOUN страны/NOUN военного/ADJ положения/NOUN ноября/NOUN проголосовали/VERB депутаты/NOUN верховной/ADJ рады/PROPN планировалось/VERB что/SCONJ положение/NOUN начнет/VERB действовать/VERB с/ADP мск/NOUN ноября/NOUN российские/ADJ военные/ADJ инструкторы/NOUN тренируют/VERB армию/NOUN центральноафриканской/ADJ республики/PROPN видеосюжет/NOUN об/ADP этом/PRON опубликовал/VERB телеканал/NOUN на/ADP в/ADP репортаже/NOUN размещенном/VERB ноября/NOUN показано/VERB как/SCONJ проходят/VERB тренировки/NOUN военных/NOUN в/ADP беренго/PROPN где/ADV ранее/ADV находилась/VERB резиденция/NOUN лидера/NOUN цар/PROPN бокассы/PROPN лица/NOUN российских/ADJ инструкторов/NOUN на/ADP кадрах/NOUN скрыты/VERB на/ADP видео/NOUN также/ADV присутствует/VERB советник/NOUN президента/NOUN цар/PROPN по/ADP национальной/ADJ безопасности/NOUN валерий/PROPN захаров/PROPN он/PRON дает/VERB интервью/NOUN в/ADP котором/PRON отрицает/VERB что/SCONJ инструктирующие/VERB африканцев/NOUN россияне/NOUN связаны/VERB с/ADP чвк/PROPN вагнера/PROPN по/ADP его/DET словам/NOUN это/PRON обычные/ADJ российские/ADJ резервисты/NOUN в/ADP конце/NOUN октября/NOUN россия/PROPN заявляла/VERB о/ADP готовности/NOUN отправить/VERB в/ADP цар/PROPN дополнительных/ADJ военных/ADJ инструкторов/NOUN ранее/ADV сообщалось/VERB что/SCONJ российских/ADJ специалистов/NOUN были/AUX направлены/VERB в/ADP страну/NOUN по/ADP договоренности/NOUN с/ADP ее/DET правительством/NOUN и/CCONJ с/ADP одобрения/NOUN совета/PROPN безопасности/PROPN оон/PROPN житель/NOUN американского/ADJ штата/NOUN южная/ADJ каролина/PROPN занимавшийся/VERB подводной/ADJ охотой/NOUN на/ADP багамах/PROPN подвергся/VERB нападению/NOUN карибской/ADJ рифовой/ADJ акулы/NOUN об/ADP этом/PRON сообщает/VERB издание/NOUN двухметровая/ADJ рыба/NOUN подплыла/VERB к/ADP уиллу/PROPN краузе/PROPN со/ADP спины/NOUN сжала/VERB зубы/NOUN на/ADP его/DET голове/NOUN и/CCONJ шее/NOUN а/CCONJ затем/ADV отпустила/VERB его/PRON по/ADP словам/NOUN мужчины/NOUN он/PRON не/PART видел/VERB акулы/NOUN и/CCONJ лишь/PART ощутил/VERB сильный/ADJ удар/NOUN после/ADP этого/PRON раздался/VERB громкий/ADJ хруст/NOUN и/CCONJ он/PRON почувствовал/VERB что/SCONJ у/ADP него/PRON течет/VERB кровь/NOUN я/PRON не/PART понял/VERB что/SCONJ это/PRON был/AUX акулий/ADJ укус/NOUN пока/SCONJ не/PART оказался/VERB на/ADP поверхности/NOUN вспоминает/VERB краузе/PROPN момент/NOUN нападения/NOUN снял/VERB на/ADP видео/NOUN его/PRON товарищ/NOUN они/PRON быстро/ADV выбрались/VERB из/ADP воды/NOUN в/ADP лодку/NOUN и/CCONJ оказались/VERB в/ADP безопасности/NOUN подводный/ADJ охотник/NOUN отделался/VERB сотрясением/NOUN мозга/NOUN на/ADP рану/NOUN наложили/VERB швы/NOUN напавшая/VERB на/ADP него/PRON акула/NOUN относится/VERB к/ADP виду/NOUN максимальная/ADJ зарегистрированная/VERB длина/NOUN этих/DET рыб/NOUN составляет/VERB сантиметров/NOUN они/PRON считаются/VERB опасными/ADJ для/ADP человека/NOUN но/CCONJ не/PART агрессивны/ADJ участница/NOUN американского/ADJ семейство/NOUN кардашьян/PROPN кортни/PROPN кардашьян/PROPN сфотографировалась/VERB для/ADP журнала/NOUN серия/NOUN фотографий/NOUN появились/VERB в/ADP сети/NOUN во/ADP вторник/NOUN ноября/NOUN для/ADP обложки/NOUN декабрьского/ADJ номера/NOUN телезвезда/NOUN снялась/VERB в/ADP белом/ADJ боди/NOUN сидя/VERB в/ADP кресле/NOUN на/ADP других/ADJ фотографиях/NOUN она/PRON позирует/VERB полностью/ADV обнаженной/VERB и/CCONJ прикрывает/VERB тело/NOUN руками/NOUN публикация/NOUN от/ADP ноя/PROPN в/ADP автор/NOUN фотографий/NOUN американский/ADJ фотограф/NOUN майкл/PROPN шварц/PROPN по/ADP мнению/NOUN издания/NOUN своим/DET участием/NOUN в/ADP откровенной/ADJ фотосессии/NOUN женщина/NOUN доказала/VERB что/SCONJ она/PRON не/PART последняя/ADJ в/ADP семье/NOUN на/ADP кого/PRON хочется/VERB смотреть/VERB как/SCONJ ее/PRON окрестила/VERB сестра/NOUN ким/PROPN в/ADP одном/NUM из/ADP эпизодов/NOUN шоу/NOUN семейство/NOUN кардашьян/PROPN в/ADP ноябре/NOU ...
#
# Untagged: с мск ноября за введение в ряде областей страны военного положения ноября проголосовали депутаты верховной рады планировалось что положение начнет действовать с мск ноября российские военные инструкторы тренируют армию центральноафриканской республики видеосюжет об этом опубликовал телеканал на в репортаже размещенном ноября показано как проходят тренировки военных в беренго где ранее находилась резиденция лидера цар бокассы лица российских инструкторов на кадрах скрыты на видео также присутствует советник президента цар по национальной безопасности валерий захаров он дает интервью в котором отрицает что инструктирующие африканцев россияне связаны с чвк вагнера по его словам это обычные российские резервисты в конце октября россия заявляла о готовности отправить в цар дополнительных военных инструкторов ранее сообщалось что российских специалистов были направлены в страну по договоренности с ее правительством и с одобрения совета безопасности оон житель американского штата южная каролина занимавшийся подводной охотой на багамах подвергся нападению карибской рифовой акулы об этом сообщает издание двухметровая рыба подплыла к уиллу краузе со спины сжала зубы на его голове и шее а затем отпустила его по словам мужчины он не видел акулы и лишь ощутил сильный удар после этого раздался громкий хруст и он почувствовал что у него течет кровь я не понял что это был акулий укус пока не оказался на поверхности вспоминает краузе момент нападения снял на видео его товарищ они быстро выбрались из воды в лодку и оказались в безопасности подводный охотник отделался сотрясением мозга на рану наложили швы напавшая на него акула относится к виду максимальная зарегистрированная длина этих рыб составляет сантиметров они считаются опасными для человека но не агрессивны участница американского семейство кардашьян кортни кардашьян сфотографировалась для журнала серия фотографий появились в сети во вторник ноября для обложки декабрьского номера телезвезда снялась в белом боди сидя в кресле на других фотографиях она позирует полностью обнаженной и прикрывает тело руками публикация от ноя в автор фотографий американский фотограф майкл шварц по мнению издания своим участием в откровенной фотосессии женщина доказала что она не последняя в семье на кого хочется смотреть как ее окрестила сестра ким в одном из эпизодов шоу семейство кардашьян в ноябре ким призналась телеведущей эллен дедженерес что ее супруг канье уэст иногда тревожится обнаженных фотографий жены в она заявила что обычно ее муж беспокоится подобных снимков но иногда может и поддержать бывший нападающий владикавказской алании и сборной грузии георгий деметрадзе прокомментировал арест российских футболистов александра кокорина и павла мамаева его слова приводит деметрадзе отсидевший в грузинской тюрьме два с половиной года считает что обоих футболистов следовало выпустить под залог по его мнению суд должен был учесть вклад кокорина и мамаева в российский футбол что могу им посоветовать терпеть и ждать освобождения думаю к ним относятся хорошо с уважением они заслуженные люди в россии считает деметрадзе мамаев и кокорин были помещены под стражу как фигуранты трех уголовных дел возбужденных по статьям хулиганство и побои срок задержания футболистов истекает декабря октября апелляции защиты мамаева и кокорина о смене меры пресечения были отклонены судом октября футболисты стали зачинщиками двух драк в москве вначале они избили водителя телеведущей ольги ушаковой а затем отправились в одну из столичных кофеен где избили чиновников представителя минпромторга дениса пака и генерального директора фгуп нами сергея гайсина деметрадзе известен по выступлениям за аланию локомотив киевское динамо а также испанский реал сосьедад в году он был арестован за связи с организованной преступностью и пробыл два с половиной года в грузинской тюрьме в результате возгорания на строящемся на адмиралтейских верфях в ледоколе виктор черномырдин пострадали два человека они обратились в травмпункт с взрывной тр ...
#
# HMM-tagged: с/ADP мск/NOUN ноября/NOUN за/ADP введение/NOUN в/ADP ряде/NOUN областей/NOUN страны/NOUN военного/ADJ положения/NOUN ноября/NOUN проголосовали/VERB депутаты/NOUN верховной/ADJ рады/PROPN планировалось/VERB что/SCONJ положение/NOUN начнет/VERB действовать/VERB с/ADP мск/NOUN ноября/NOUN российские/ADJ военные/ADJ инструкторы/NOUN тренируют/VERB армию/NOUN центральноафриканской/ADJ республики/NOUN видеосюжет/NOUN об/ADP этом/PRON опубликовал/VERB телеканал/NOUN на/ADP в/ADP репортаже/NOUN размещенном/VERB ноября/NOUN показано/VERB как/SCONJ проходят/VERB тренировки/NOUN военных/NOUN в/ADP беренго/PROPN где/ADV ранее/ADV находилась/VERB резиденция/NOUN лидера/NOUN цар/PROPN бокассы/PROPN лица/NOUN российских/ADJ инструкторов/NOUN на/ADP кадрах/NOUN скрыты/VERB на/ADP видео/NOUN также/ADV присутствует/VERB советник/NOUN президента/NOUN цар/PROPN по/ADP национальной/ADJ безопасности/NOUN валерий/PROPN захаров/PROPN он/PRON дает/VERB интервью/NOUN в/ADP котором/PRON отрицает/VERB что/SCONJ инструктирующие/VERB африканцев/NOUN россияне/NOUN связаны/VERB с/ADP чвк/PROPN вагнера/PROPN по/ADP его/DET словам/NOUN это/PRON обычные/ADJ российские/ADJ резервисты/NOUN в/ADP конце/NOUN октября/NOUN россия/PROPN заявляла/VERB о/ADP готовности/NOUN отправить/VERB в/ADP цар/PROPN дополнительных/ADJ военных/ADJ инструкторов/NOUN ранее/ADV сообщалось/VERB что/SCONJ российских/ADJ специалистов/NOUN были/AUX направлены/VERB в/ADP страну/NOUN по/ADP договоренности/NOUN с/ADP ее/DET правительством/NOUN и/CCONJ с/ADP одобрения/NOUN совета/NOUN безопасности/NOUN оон/PROPN житель/NOUN американского/ADJ штата/NOUN южная/ADJ каролина/PROPN занимавшийся/VERB подводной/ADJ охотой/NOUN на/ADP багамах/PROPN подвергся/VERB нападению/NOUN карибской/ADJ рифовой/ADJ акулы/NOUN об/ADP этом/PRON сообщает/VERB издание/NOUN двухметровая/ADJ рыба/NOUN подплыла/VERB к/ADP уиллу/PROPN краузе/PROPN со/ADP спины/NOUN сжала/VERB зубы/NOUN на/ADP его/DET голове/NOUN и/CCONJ шее/NOUN а/CCONJ затем/ADV отпустила/VERB его/PRON по/ADP словам/NOUN мужчины/NOUN он/PRON не/PART видел/VERB акулы/NOUN и/CCONJ лишь/PART ощутил/VERB сильный/ADJ удар/NOUN после/ADP этого/PRON раздался/VERB громкий/ADJ хруст/NOUN и/CCONJ он/PRON почувствовал/VERB что/SCONJ у/ADP него/PRON течет/VERB кровь/NOUN я/PRON не/PART понял/VERB что/SCONJ это/PRON был/AUX акулий/ADJ укус/NOUN пока/ADV не/PART оказался/VERB на/ADP поверхности/NOUN вспоминает/VERB краузе/PROPN момент/NOUN нападения/NOUN снял/VERB на/ADP видео/NOUN его/DET товарищ/NOUN они/PRON быстро/ADV выбрались/VERB из/ADP воды/NOUN в/ADP лодку/NOUN и/CCONJ оказались/VERB в/ADP безопасности/NOUN подводный/ADJ охотник/NOUN отделался/VERB сотрясением/NOUN мозга/NOUN на/ADP рану/NOUN наложили/VERB швы/NOUN напавшая/VERB на/ADP него/PRON акула/NOUN относится/VERB к/ADP виду/NOUN максимальная/ADJ зарегистрированная/VERB длина/NOUN этих/DET рыб/NOUN составляет/VERB сантиметров/NOUN они/PRON считаются/VERB опасными/ADJ для/ADP человека/NOUN но/CCONJ не/PART агрессивны/ADJ участница/NOUN американского/ADJ семейство/NOUN кардашьян/PROPN кортни/PROPN кардашьян/PROPN сфотографировалась/VERB для/ADP журнала/NOUN серия/NOUN фотографий/NOUN появились/VERB в/ADP сети/NOUN во/ADP вторник/NOUN ноября/NOUN для/ADP обложки/NOUN декабрьского/ADJ номера/NOUN телезвезда/NOUN снялась/VERB в/ADP белом/ADJ боди/NOUN сидя/VERB в/ADP кресле/NOUN на/ADP других/ADJ фотографиях/NOUN она/PRON позирует/VERB полностью/ADV обнаженной/VERB и/CCONJ прикрывает/VERB тело/NOUN руками/NOUN публикация/NOUN от/ADP ноя/PROPN в/ADP автор/NOUN фотографий/NOUN американский/ADJ фотограф/NOUN майкл/PROPN шварц/PROPN по/ADP мнению/NOUN издания/NOUN своим/DET участием/NOUN в/ADP откровенной/ADJ фотосессии/NOUN женщина/NOUN доказала/VERB что/SCONJ она/PRON не/PART последняя/ADJ в/ADP семье/NOUN на/ADP кого/PRON хочется/VERB смотреть/VERB как/SCONJ ее/PRON окрестила/VERB сестра/NOUN ким/PROPN в/ADP одном/NUM из/ADP эпизодов/NOUN шоу/NOUN семейство/NOUN кардашьян/PROPN в/ADP ноябре/NOU ...
#
# Entropy: 53.96968156491055
#
# ------------------------------------------------------------
# accuracy over 1000 tokens: 97.90

# %% [markdown]
# Модель неплохо справляется с предсказанием частей речи для сэмпла слов, которые расположены в начале датасета. Если говорить о качестве на рандомном сэмпле, то явно присутствует проблема зацикливания, как можно видеть из второго теста.

# %% [markdown]
# ### Качество модели на тест датасете

# %%
model.test([test_data[0:1000]], verbose=True)
# Out:
# Test: клиентов/NOUN поскольку/SCONJ уже/ADV более/ADV лет/NOUN в/ADP компании/NOUN широко/ADV используется/VERB ручная/ADJ работа/NOUN высококвалифицированных/ADJ французских/ADJ ремесленников/NOUN компания/NOUN размещается/VERB в/ADP том/DET же/PART фабричном/ADJ здании/NOUN которое/PRON было/AUX построено/VERB в/ADP бабушкой/NOUN софи/PROPN грегуар/PROPN я/PRON выросла/VERB на/ADP фабрике/NOUN ею/PRON всегда/ADV руководили/VERB женщины/NOUN три/NUM поколения/NOUN женщин/NOUN бабушка/NOUN которая/PRON основала/VERB компанию/NOUN мама/NOUN которая/PRON начала/VERB сотрудничать/VERB с/ADP крупными/ADJ товаров/NOUN класса/NOUN люкс/NOUN и/CCONJ я/PRON знакомиться/VERB с/ADP бизнесом/NOUN софи/PROPN начала/VERB с/ADP детства/NOUN буквально/ADV росла/VERB на/ADP фабрике/NOUN мама/NOUN приводила/VERB меня/PRON в/ADP цех/NOUN и/CCONJ я/PRON часами/NOUN рылась/VERB в/ADP перчатках/NOUN примеряя/VERB их/PRON вспоминает/VERB софи/PROPN на/ADP вопрос/NOUN о/ADP трендах/NOUN софи/PROPN грегуар/PROPN отвечает/VERB что/SCONJ новый/ADJ тренд/NOUN то/PRON что/SCONJ молодые/ADJ женщины/NOUN меняют/VERB автомобиль/NOUN на/ADP велосипед/NOUN или/CCONJ мопед/NOUN а/CCONJ чтобы/SCONJ оставаться/VERB женственной/ADJ за/ADP рулем/NOUN мопеда/NOUN женщине/NOUN нужна/ADJ пара/NOUN изящных/ADJ перчаток/NOUN с/ADP вырезом/NOUN как/SCONJ носили/VERB автомобилисты/NOUN тогда/ADV когда/ADV почти/ADV все/DET машины/NOUN были/AUX открытыми/ADJ на/ADP вопрос/NOUN о/ADP том/PRON сложно/ADJ ли/PART женщине/NOUN в/ADP мужском/ADJ мире/NOUN софи/PROPN отвечает/VERB что/SCONJ женственность/NOUN сложное/ADJ понятие/NOUN в/ADP современном/ADJ мире/NOUN мужчины/NOUN и/CCONJ женщины/NOUN могут/VERB одинаково/ADV успешно/ADV выполнять/VERB одинаковую/ADJ работу/NOUN когда/SCONJ я/PRON получила/VERB орден/NOUN почетного/ADJ легиона/NOUN за/ADP то/PRON что/SCONJ выкупила/VERB нашу/DET семейную/ADJ компанию/NOUN ранее/ADV проданную/VERB зарубежной/ADJ корпорации/NOUN мой/DET муж/NOUN был/AUX счастлив/ADJ и/CCONJ польщен/ADJ партнерам/NOUN в/ADP браке/NOUN не/PART стоит/VERB конкурировать/VERB компания/NOUN основана/VERB в/ADP году/NOUN во/ADP французском/ADJ местечке/NOUN специализируется/VERB на/ADP аксессуарах/NOUN класса/NOUN люкс/NOUN преимущественно/ADV перчатках/NOUN ручной/ADJ работы/NOUN из/ADP натуральной/ADJ кожи/NOUN выпускает/VERB как/SCONJ собственные/ADJ коллекции/NOUN так/ADV и/PART совместные/ADJ коллекции/NOUN с/ADP другими/ADJ брендами/NOUN а/CCONJ также/ADV работает/VERB на/ADP заказ/NOUN сотрудничает/VERB с/ADP модными/ADJ дизайнерами/NOUN в/ADP том/DET числе/NOUN с/ADP французским/ADJ модельером/NOUN де/PART кастельбажаком/PROPN в/ADP россии/PROPN марка/NOUN представлена/VERB в/ADP сети/NOUN опубликована/VERB памятка/NOUN для/ADP китайских/ADJ туристов/NOUN испытывающих/VERB трудности/NOUN с/ADP пониманием/NOUN культуры/NOUN поведения/NOUN в/ADP россии/PROPN брошюра/NOUN китайская/ADJ грамота/NOUN доступна/ADJ на/ADP сайте/NOUN туту/NOUN ру/NOUN это/PRON восемь/NUM советов/NOUN которые/PRON помогут/VERB китайскому/ADJ туристу/NOUN вписаться/VERB в/ADP общество/NOUN понять/VERB другую/ADJ культуру/NOUN и/CCONJ не/PART попадать/VERB в/ADP неловкие/ADJ ситуации/NOUN ее/PRON можно/ADV скачать/VERB и/CCONJ повесить/VERB в/ADP отеле/NOUN магазине/NOUN добавить/VERB в/ADP буклет/NOUN или/CCONJ книгу/NOUN объяснили/VERB специалисты/NOUN сервиса/NOUN в/ADP частности/NOUN гостям/NOUN из/ADP китая/PROPN рекомендовали/VERB не/PART прикасаться/VERB к/ADP людям/NOUN в/ADP общественных/ADJ местах/NOUN а/CCONJ также/ADV спрашивать/VERB разрешение/NOUN прежде/ADV чем/SCONJ сфотографировать/VERB незнакомцев/NOUN затем/ADV иностранцев/NOUN предупредили/VERB что/SCONJ отношение/NOUN к/ADP торгу/NOUN в/ADP нетуристических/ADJ местах/NOUN может/VERB быть/AUX не/PART очень/ADV дружелюбное/ADJ если/SCONJ вы/PRON видите/VERB что/SCONJ человек/NOUN не/PART доволен/ADJ пора/NOUN останавливаться/VERB обычно/ADV это/PRON случается/VERB после/ADP предложения/NOUN цены/NOUN ниже/A ...
#
# Untagged: клиентов поскольку уже более лет в компании широко используется ручная работа высококвалифицированных французских ремесленников компания размещается в том же фабричном здании которое было построено в бабушкой софи грегуар я выросла на фабрике ею всегда руководили женщины три поколения женщин бабушка которая основала компанию мама которая начала сотрудничать с крупными товаров класса люкс и я знакомиться с бизнесом софи начала с детства буквально росла на фабрике мама приводила меня в цех и я часами рылась в перчатках примеряя их вспоминает софи на вопрос о трендах софи грегуар отвечает что новый тренд то что молодые женщины меняют автомобиль на велосипед или мопед а чтобы оставаться женственной за рулем мопеда женщине нужна пара изящных перчаток с вырезом как носили автомобилисты тогда когда почти все машины были открытыми на вопрос о том сложно ли женщине в мужском мире софи отвечает что женственность сложное понятие в современном мире мужчины и женщины могут одинаково успешно выполнять одинаковую работу когда я получила орден почетного легиона за то что выкупила нашу семейную компанию ранее проданную зарубежной корпорации мой муж был счастлив и польщен партнерам в браке не стоит конкурировать компания основана в году во французском местечке специализируется на аксессуарах класса люкс преимущественно перчатках ручной работы из натуральной кожи выпускает как собственные коллекции так и совместные коллекции с другими брендами а также работает на заказ сотрудничает с модными дизайнерами в том числе с французским модельером де кастельбажаком в россии марка представлена в сети опубликована памятка для китайских туристов испытывающих трудности с пониманием культуры поведения в россии брошюра китайская грамота доступна на сайте туту ру это восемь советов которые помогут китайскому туристу вписаться в общество понять другую культуру и не попадать в неловкие ситуации ее можно скачать и повесить в отеле магазине добавить в буклет или книгу объяснили специалисты сервиса в частности гостям из китая рекомендовали не прикасаться к людям в общественных местах а также спрашивать разрешение прежде чем сфотографировать незнакомцев затем иностранцев предупредили что отношение к торгу в нетуристических местах может быть не очень дружелюбное если вы видите что человек не доволен пора останавливаться обычно это случается после предложения цены ниже утверждают авторы памятки эксперты туту ру отметили что россияне ценят тишину после а также уважают принцип соблюдения очереди в россии принято заказывать порционные блюда и ходить с плотно застегнутой одеждой сказано в брошюре с другой стороны у нас не принято ходить в куртке по дому или сидеть в куртке в кафе пишут специалисты в сентябре года турстат назвал по числу туристов в россии так на первом месте оказались жители украины миллиона на втором миллиона а третью позицию занял китай житель москвы выставил на продажу квартиру в которой прописана и проживает его мать сам он являясь собственником жилья живет в эквадоре с женой и ребенком передают вести наталья малицкая обращалась в суды но проиграла как отмечает издание несколько лет назад пожилая женщина была больна поэтому попросила сына приватизировать квартиру и записать на себя она получила жилье от строительного предприятия на котором трудилась позже пенсионерка поправилась а сын женился и уехал они сын и его супруга не работают живут на деньги которые получили от продажи дачи которую якобы для меня построили от продажи квартиры жены теперь вот наверное те деньги проели нужно эту продать срочно рассказывает малицкая женщину по ее словам постоянно тревожат потенциальные покупатели которые просят осмотреть жилье летом она уезжает в деревню но зимой возвращается в квартиру так как сельская изба не отапливается юристы отмечают что жилая площадь с обременением интересна прежде всего черным риелторам однако могут найтись те которые приобретя ее оставят пожилую женщину в покое они добавляют что в законодательстве на этот счет существуют значите ...
#
# HMM-tagged: клиентов/PRON поскольку/PRON уже/PRON более/PRON лет/PRON в/PRON компании/PRON широко/PRON используется/PRON ручная/PRON работа/PRON высококвалифицированных/PRON французских/PRON ремесленников/PRON компания/PRON размещается/PRON в/PRON том/PRON же/PRON фабричном/PRON здании/PRON которое/PRON было/PRON построено/PRON в/PRON бабушкой/PRON софи/PRON грегуар/PRON я/PRON выросла/PRON на/PRON фабрике/PRON ею/PRON всегда/PRON руководили/PRON женщины/PRON три/PRON поколения/PRON женщин/PRON бабушка/PRON которая/PRON основала/PRON компанию/PRON мама/PRON которая/PRON начала/PRON сотрудничать/PRON с/PRON крупными/PRON товаров/PRON класса/PRON люкс/PRON и/PRON я/PRON знакомиться/PRON с/PRON бизнесом/PRON софи/PRON начала/PRON с/PRON детства/PRON буквально/PRON росла/PRON на/PRON фабрике/PRON мама/PRON приводила/PRON меня/PRON в/PRON цех/PRON и/PRON я/PRON часами/PRON рылась/PRON в/PRON перчатках/PRON примеряя/PRON их/PRON вспоминает/PRON софи/PRON на/PRON вопрос/PRON о/PRON трендах/PRON софи/PRON грегуар/PRON отвечает/PRON что/PRON новый/PRON тренд/PRON то/PRON что/PRON молодые/PRON женщины/PRON меняют/PRON автомобиль/PRON на/PRON велосипед/PRON или/PRON мопед/PRON а/PRON чтобы/PRON оставаться/PRON женственной/PRON за/PRON рулем/PRON мопеда/PRON женщине/PRON нужна/PRON пара/PRON изящных/PRON перчаток/PRON с/PRON вырезом/PRON как/PRON носили/PRON автомобилисты/PRON тогда/PRON когда/PRON почти/PRON все/PRON машины/PRON были/PRON открытыми/PRON на/PRON вопрос/PRON о/PRON том/PRON сложно/PRON ли/PRON женщине/PRON в/PRON мужском/PRON мире/PRON софи/PRON отвечает/PRON что/PRON женственность/PRON сложное/PRON понятие/PRON в/PRON современном/PRON мире/PRON мужчины/PRON и/PRON женщины/PRON могут/PRON одинаково/PRON успешно/PRON выполнять/PRON одинаковую/PRON работу/PRON когда/PRON я/PRON получила/PRON орден/PRON почетного/PRON легиона/PRON за/PRON то/PRON что/PRON выкупила/PRON нашу/PRON семейную/PRON компанию/PRON ранее/PRON проданную/PRON зарубежной/PRON корпорации/PRON мой/PRON муж/PRON был/PRON счастлив/PRON и/PRON польщен/PRON партнерам/PRON в/PRON браке/PRON не/PRON стоит/PRON конкурировать/PRON компания/PRON основана/PRON в/PRON году/PRON во/PRON французском/PRON местечке/PRON специализируется/PRON на/PRON аксессуарах/PRON класса/PRON люкс/PRON преимущественно/PRON перчатках/PRON ручной/PRON работы/PRON из/PRON натуральной/PRON кожи/PRON выпускает/PRON как/PRON собственные/PRON коллекции/PRON так/PRON и/PRON совместные/PRON коллекции/PRON с/PRON другими/PRON брендами/PRON а/PRON также/PRON работает/PRON на/PRON заказ/PRON сотрудничает/PRON с/PRON модными/PRON дизайнерами/PRON в/PRON том/PRON числе/PRON с/PRON французским/PRON модельером/PRON де/PRON кастельбажаком/PRON в/PRON россии/PRON марка/PRON представлена/PRON в/PRON сети/PRON опубликована/PRON памятка/PRON для/PRON китайских/PRON туристов/PRON испытывающих/PRON трудности/PRON с/PRON пониманием/PRON культуры/PRON поведения/PRON в/PRON россии/PRON брошюра/PRON китайская/PRON грамота/PRON доступна/PRON на/PRON сайте/PRON туту/PRON ру/PRON это/PRON восемь/PRON советов/PRON которые/PRON помогут/PRON китайскому/PRON туристу/PRON вписаться/PRON в/PRON общество/PRON понять/PRON другую/PRON культуру/PRON и/PRON не/PRON попадать/PRON в/PRON неловкие/PRON ситуации/PRON ее/PRON можно/PRON скачать/PRON и/PRON повесить/PRON в/PRON отеле/PRON магазине/PRON добавить/PRON в/PRON буклет/PRON или/PRON книгу/PRON объяснили/PRON специалисты/PRON сервиса/PRON в/PRON частности/PRON гостям/PRON из/PRON китая/PRON рекомендовали/PRON не/PRON прикасаться/PRON к/PRON людям/PRON в/PRON общественных/PRON местах/PRON а/PRON также/PRON спрашивать/PRON разрешение/PRON прежде/PRON чем/PRON сфотографировать/PRON незнакомцев/PRON затем/PRON иностранцев/PRON предупредили/PRON что/PRON отношение/PRON к/PRON торгу/PRON в/PRON нетуристических/PRON местах/PRON может/PRON быть/PRON не/PRON очень/PRON дружелюбное/PRON если/PRON вы/PRON видите/PRON что/PRON человек/PRON не/PRON доволен/PRON пора/PRON останавливать ...
#
# Entropy: -1.3000000000000004e+301
#
# ------------------------------------------------------------
# accuracy over 1000 tokens: 6.90

# %% [markdown]
# ### Точность предсказания по тэгам

# %%
tagged_test = model.tag(list(transpose(test_data[0:1000])[0]))
unique, counts = nunique(transpose(tagged_test)[1], return_counts=True)
tagged_dict = dict(zip(unique, counts))
unique, counts = nunique(transpose(test_data)[1], return_counts=True)
test_dict = dict(zip(unique, counts))

# %% [markdown]
# Аналогичная проблема на тестовом датасете.

# %% [markdown]
# ## 3. Оптимальный порядок языковой модели

# %%
def ngrams_and_prefix_counts(tokens, n_max):
    # словарь n-грамм и их частот
    ngrams_counts = {}
    # словарь n-граммных префиксов и их частот
    prefix_counts = {}
    
    n = len(tokens)
    for i in range(n_max):
        ngrams_counts[i + 1] = Counter([tuple(tokens[j : j + i + 1]) for j in range(n - i)])
        prefix_counts[i + 1] = Counter([tuple(tokens[j : j + i] + ['*']) for j in range(n - i)])

    return ngrams_counts, prefix_counts

def unigram_probas(ngram_counts):
    p1 = {}
    n = sum(ngram_counts[1].values())
    for w in ngram_counts[1]:
        p1[w] = ngram_counts[1][w] / n
    return p1


def bigram_probas(ngram_counts, prefix_counts):
    p2 = {}
    for w in ngram_counts[2]:
        pre_w = tuple([w[0]] + ['*'])
        p2[u'{1}|{0}'.format(*w)] = ngram_counts[2][w] / prefix_counts[2][pre_w]
    return p2


def trigram_probas(ngram_counts, prefix_counts):
    p3 = {}
    for w in ngram_counts[3]:
        pre_w = w[:2] + tuple(['*'])
        p3[u'{2}|{1},{0}'.format(*w)] = ngram_counts[3][w] / prefix_counts[3][pre_w]
    return p3
  
def random_n_dict_items(d: dict, n: int) -> dict:
  """gets random n items of a sorted dict by values"""
  return [(d[x], x) for x in take(n, d)]

# %%
ngram_counts, prefix_counts = ngrams_and_prefix_counts(tokens, 3)

# %%
p1 = unigram_probas(ngram_counts)
random_n_dict_items(p1, 15)
# Out:
# [(0.010612690011038262, (('по', 'ADP'),)),
#  (1.0639288231617304e-05, (('социальным', 'ADJ'),)),
#  (0.00010173819371484048, (('вопросам', 'NOUN'),)),
#  (4.654688601332571e-05, (('татьяна', 'PROPN'),)),
#  (5.319644115808652e-06, (('голикова', 'PROPN'),)),
#  (0.00038035455428031865, (('рассказала', 'VERB'),)),
#  (0.05025002327344301, (('в', 'ADP'),)),
#  (2.8593087122471508e-05, (('каких', 'DET'),)),
#  (0.00011836208157674252, (('регионах', 'NOUN'),)),
#  (0.003334751905097549, (('россии', 'PROPN'),)),
#  (8.64442168818906e-06, (('зафиксирована', 'VERB'),)),
#  (0.00016690383413349647, (('наиболее', 'ADV'),)),
#  (1.9948665434282447e-05, (('высокая', 'ADJ'),)),
#  (9.309377202665141e-06, (('смертность', 'NOUN'),)),
#  (0.0032230393786655672, (('от', 'ADP'),))]

# %%
p2 = bigram_probas(ngram_counts, prefix_counts)
random_n_dict_items(p2, 15)
# Out:
# [(0.0004385964912280702, "('социальным', 'ADJ')|('по', 'ADP')"),
#  (0.125, "('вопросам', 'NOUN')|('социальным', 'ADJ')"),
#  (0.013071895424836602, "('татьяна', 'PROPN')|('вопросам', 'NOUN')"),
#  (0.08571428571428572, "('голикова', 'PROPN')|('татьяна', 'PROPN')"),
#  (0.125, "('рассказала', 'VERB')|('голикова', 'PROPN')"),
#  (0.06818181818181818, "('в', 'ADP')|('рассказала', 'VERB')"),
#  (0.00018526115205970702, "('каких', 'DET')|('в', 'ADP')"),
#  (0.06976744186046512, "('регионах', 'NOUN')|('каких', 'DET')"),
#  (0.14606741573033707, "('россии', 'PROPN')|('регионах', 'NOUN')"),
#  (0.00019940179461615153, "('зафиксирована', 'VERB')|('россии', 'PROPN')"),
#  (0.07692307692307693, "('наиболее', 'ADV')|('зафиксирована', 'VERB')"),
#  (0.00398406374501992, "('высокая', 'ADJ')|('наиболее', 'ADV')"),
#  (0.03333333333333333, "('смертность', 'NOUN')|('высокая', 'ADJ')"),
#  (0.5, "('от', 'ADP')|('смертность', 'NOUN')"),
#  (0.004126263668248401, "('рака', 'NOUN')|('от', 'ADP')")]

# %%
p3 = trigram_probas(ngram_counts, prefix_counts)
random_n_dict_items(p3, 10)
# Out:
# [(0.2857142857142857,
#   "('вопросам', 'NOUN')|('социальным', 'ADJ'),('по', 'ADP')"),
#  (1.0, "('татьяна', 'PROPN')|('вопросам', 'NOUN'),('социальным', 'ADJ')"),
#  (1.0, "('голикова', 'PROPN')|('татьяна', 'PROPN'),('вопросам', 'NOUN')"),
#  (0.16666666666666666,
#   "('рассказала', 'VERB')|('голикова', 'PROPN'),('татьяна', 'PROPN')"),
#  (1.0, "('в', 'ADP')|('рассказала', 'VERB'),('голикова', 'PROPN')"),
#  (0.02564102564102564, "('каких', 'DET')|('в', 'ADP'),('рассказала', 'VERB')"),
#  (0.14285714285714285, "('регионах', 'NOUN')|('каких', 'DET'),('в', 'ADP')"),
#  (0.6666666666666666,
#   "('россии', 'PROPN')|('регионах', 'NOUN'),('каких', 'DET')"),
#  (0.038461538461538464,
#   "('зафиксирована', 'VERB')|('россии', 'PROPN'),('регионах', 'NOUN')"),
#  (1.0, "('наиболее', 'ADV')|('зафиксирована', 'VERB'),('россии', 'PROPN')")]

# %%
def chi2_stat(p_small, p_big, tokens, model_type: str):
    stat_small = []
    stat_big = []
    n = len(tokens)
    for i in range(n - 2):
        if model_type == "3_to_2":
            w = tokens[i : i + 3]
            ngram_big = '{2}|{1},{0}'.format(*w)
            ngram_small = '{1}|{0}'.format(*w)
        elif model_type == "2_to_1":
            w = tokens[i : i + 2]
            ngram_big = '{1}|{0}'.format(*w)
            ngram_small = '{0}'.format(*w)
    return - 2 * nsum(stat_small) + 2 * nsum(stat_big)

# %%
stat_32 = chi2_stat(p2, p3, tokens, model_type="3_to_2")
print(f'p-value for 3 -> 2 reduction: {1 - chi2(len(p3) * ((len(p3) - 1) ** 2) - 1).cdf(stat_32):.2f}')
# Out:
# p-value for 3 -> 2 reduction: 1.00

# %%
stat_21 = chi2_stat(p1, p2, tokens, model_type="2_to_1")
print(f'p-value for 2 -> reduction: {1 - chi2(len(p2) * ((len(p2) - 1) ** 2) - 1).cdf(stat_21):.2f}')
# Out:
# p-value for 2 -> reduction: 1.00

# %% [markdown]
# # Итоги

# %% [markdown]
# * Оптимальная языковая модель имеет порядок 1 (использует монограммы).
#
# * Качество марковской модели получилось довольно низким. Присутствует проблема зацикливания.
